# %%
import pandas as pd
import os

# %%
pwd
# Out:
# 'C:\\Users\\Amar\\Desktop'

# %%
bikes = pd.read_csv(r'udemy/Master Data Analysis/data/bikes.csv')

# %%
bikes.head()
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4    13168  Subscriber   Male  2013-07-01 11:16:00  2013-07-01 11:18:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
# 3           667       Carpenter St & Huron St       41.894556
# 4           130        Damen Ave & Pierce Ave       41.909396
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St     41.900960
# ...

# %%
filt = bikes['tripduration'] > 5000

bikes[filt].head()
# Out:
#      trip_id    usertype  gender            starttime             stoptime  \
# 18     40924  Subscriber    Male  2013-07-09 13:12:00  2013-07-09 14:42:00
# 40     61401  Subscriber  Female  2013-07-14 14:08:00  2013-07-14 15:53:00
# 77     87005  Subscriber  Female  2013-07-21 11:35:00  2013-07-21 13:54:00
# 335   323274  Subscriber    Male  2013-08-25 17:20:00  2013-08-25 19:26:00
# 504   442585  Subscriber    Male  2013-09-08 03:43:00  2013-09-08 07:20:00
#
#      tripduration            from_station_name  latitude_start  \
# 18           5396      Canal St & Jackson Blvd       41.878114
# 40           6274    Wabash Ave & Roosevelt Rd       41.867173
# 77           8299           State St & 19th St       41.856594
# 335          7533     McClurg Ct & Illinois St       41.891020
# 504         13037  Dearborn Pkwy & Delaware Pl       41.899007
#
#      longitude_start  dpcapacity_start               to_station_name  \
# ...

# %%
filt1 = bikes['tripduration'] > 5000
filt2 = bikes['gender'] == 'Male'
filt = filt1 & filt2
bikes[filt].head()
# Out:
#       trip_id    usertype gender            starttime             stoptime  \
# 18      40924  Subscriber   Male  2013-07-09 13:12:00  2013-07-09 14:42:00
# 335    323274  Subscriber   Male  2013-08-25 17:20:00  2013-08-25 19:26:00
# 504    442585  Subscriber   Male  2013-09-08 03:43:00  2013-09-08 07:20:00
# 2565  1354900  Subscriber   Male  2014-04-07 17:16:00  2014-04-07 19:54:00
# 3406  1715861  Subscriber   Male  2014-05-19 09:26:00  2014-05-19 10:50:00
#
#       tripduration            from_station_name  latitude_start  \
# 18            5396      Canal St & Jackson Blvd       41.878114
# 335           7533     McClurg Ct & Illinois St       41.891020
# 504          13037  Dearborn Pkwy & Delaware Pl       41.899007
# 2565          9491      Dearborn St & Monroe St       41.881320
# 3406          5059        Franklin St & Lake St       41.885837
#
#       longitude_start  dpcapacity_start               to_station_name  \
# ...

# %%
filt = filt1 | filt2 
bikes[filt].head()
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4    13168  Subscriber   Male  2013-07-01 11:16:00  2013-07-01 11:18:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
# 3           667       Carpenter St & Huron St       41.894556
# 4           130        Damen Ave & Pierce Ave       41.909396
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St     41.900960
# ...

# %%
college = pd.read_csv(r'udemy/Master Data Analysis/data/college.csv',index_col = 'instnm')
cr = college.loc[:,'ugds_white':'ugds_unkn']
cr.head()
# Out:
#                                      ugds_white  ugds_black  ugds_hisp  \
# instnm
# Alabama A & M University                 0.0333      0.9353     0.0055
# University of Alabama at Birmingham      0.5922      0.2600     0.0283
# Amridge University                       0.2990      0.4192     0.0069
# University of Alabama in Huntsville      0.6988      0.1255     0.0382
# Alabama State University                 0.0158      0.9208     0.0121
#
#                                      ugds_asian  ugds_aian  ugds_nhpi  \
# instnm
# Alabama A & M University                 0.0019     0.0024     0.0019
# University of Alabama at Birmingham      0.0518     0.0022     0.0007
# Amridge University                       0.0034     0.0000     0.0000
# University of Alabama in Huntsville      0.0376     0.0143     0.0002
# Alabama State University                 0.0019     0.0010     0.0006
#
#                                      ugds_2mor  ugds_nra  ugds_unkn
# instnm
# ...

# %%
cr.mean()
# Out:
# ugds_white    0.510207
# ugds_black    0.189997
# ugds_hisp     0.161635
# ugds_asian    0.033544
# ugds_aian     0.013813
# ugds_nhpi     0.004569
# ugds_2mor     0.023950
# ugds_nra      0.016086
# ugds_unkn     0.045181
# dtype: float64

# %%
cr.sum(axis = 1).head()
# Out:
# instnm
# Alabama A & M University               1.0000
# University of Alabama at Birmingham    0.9999
# Amridge University                     1.0000
# University of Alabama in Huntsville    1.0000
# Alabama State University               1.0000
# dtype: float64

# %%
cr.round(2).head()
# Out:
#                                      ugds_white  ugds_black  ugds_hisp  \
# instnm
# Alabama A & M University                   0.03        0.94       0.01
# University of Alabama at Birmingham        0.59        0.26       0.03
# Amridge University                         0.30        0.42       0.01
# University of Alabama in Huntsville        0.70        0.13       0.04
# Alabama State University                   0.02        0.92       0.01
#
#                                      ugds_asian  ugds_aian  ugds_nhpi  \
# instnm
# Alabama A & M University                   0.00       0.00        0.0
# University of Alabama at Birmingham        0.05       0.00        0.0
# Amridge University                         0.00       0.00        0.0
# University of Alabama in Huntsville        0.04       0.01        0.0
# Alabama State University                   0.00       0.00        0.0
#
#                                      ugds_2mor  ugds_nra  ugds_unkn
# instnm
# ...

# %%
ins = pd.read_csv(r'udemy/Master Data Analysis/data/insurance.csv')
ins.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
ins['region'].value_counts()
# Out:
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: region, dtype: int64

# %%
ins.groupby('sex').agg({'charges':'mean'}).round(-3)
# Out:
#         charges
# sex
# female  13000.0
# male    14000.0

# %%
ins.groupby('sex').agg({'charges':['mean','count','max']}).round(-3)
# Out:
#         charges
#            mean count      max
# sex
# female  13000.0  1000  64000.0
# male    14000.0  1000  63000.0

# %%
ins.groupby(['sex','region']).agg({'charges':['mean','count','max']}).round(-3)
# Out:
#                   charges
#                      mean count      max
# sex    region
# female northeast  13000.0     0  59000.0
#        northwest  12000.0     0  55000.0
#        southeast  13000.0     0  64000.0
#        southwest  11000.0     0  49000.0
# male   northeast  14000.0     0  49000.0
#        northwest  12000.0     0  60000.0
#        southeast  16000.0     0  63000.0
#        southwest  13000.0     0  53000.0

# %%
pt = ins.pivot_table(index='sex',columns='region',
                    values = 'charges',aggfunc='mean').round(0)

# %%
pt
# Out:
# region  northeast  northwest  southeast  southwest
# sex
# female    12953.0    12480.0    13500.0    11274.0
# male      13854.0    12354.0    15880.0    13413.0

# %%
pt.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_74272170_83b1_11e9_a068_34f64b46edfcrow0_col1 {
#             background-color:  yellow;
#         }    #T_74272170_83b1_11e9_a068_34f64b46edfcrow1_col0 {
#             background-color:  yellow;
#         }    #T_74272170_83b1_11e9_a068_34f64b46edfcrow1_col2 {
#             background-color:  yellow;
#         }    #T_74272170_83b1_11e9_a068_34f64b46edfcrow1_col3 {
#             background-color:  yellow;
#         }</style>
# <table id="T_74272170_83b1_11e9_a068_34f64b46edfc" >
# <thead>    <tr>
#         <th class="index_name level0" >region</th>
#         <th class="col_heading level0 col0" >northeast</th>
#         <th class="col_heading level0 col1" >northwest</th>
#         <th class="col_heading level0 col2" >southeast</th>
#         <th class="col_heading level0 col3" >southwest</th>
#     </tr>    <tr>
#         <th class="index_name level0" >sex</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
# ...

# %%
pc = pd.read_csv(r'udemy/Master Data Analysis/data/tidy/planecrashinfo.csv')
pc.head(3)
# Out:
#                  date   time                   location              operator  \
# 0  September 17, 1908  17:18        Fort Myer, Virginia  Military - U.S. Army
# 1  September 07, 1909      ?    Juvisy-sur-Orge, France                     ?
# 2       July 12, 1912  06:30  Atlantic City, New Jersey  Military - U.S. Navy
#
#   flight_no          route           ac_type registration cn_ln  \
# 0         ?  Demonstration  Wright Flyer III            ?     1
# 1         ?       Air show    Wright Byplane          SC1     ?
# 2         ?    Test flight         Dirigible            ?     ?
#
#                        aboard                  fatalities ground  \
# 0  2   (passengers:1  crew:1)  1   (passengers:1  crew:0)      0
# 1  1   (passengers:0  crew:1)  1   (passengers:0  crew:0)      0
# 2  5   (passengers:0  crew:5)  5   (passengers:0  crew:5)      0
#
#                                              summary
# 0  During a demonstration flight, a U.S. Army fly...
# ...

# %%
pc = pd.read_csv(r'udemy/Master Data Analysis/data/tidy/planecrashinfo.csv',na_values = '?')

# %%
pc
# Out:
#                     date     time  \
# 0     September 17, 1908    17:18
# 1     September 07, 1909      NaN
# 2          July 12, 1912    06:30
# 3        August 06, 1913      NaN
# 4     September 09, 1913  c 18:30
# 5       October 17, 1913  c 10:30
# 6         March 05, 1915  c 01:00
# 7     September 03, 1915  c 15:20
# 8          July 28, 1916      NaN
# 9     September 24, 1916  c 01:00
# 10      October 01, 1916  c 23:45
# 11     November 21, 1916      NaN
# 12     November 28, 1916  c 23:45
# 13        March 04, 1917      NaN
# 14        March 30, 1917      NaN
# 15          May 14, 1917  c 05:15
# 16         June 14, 1917  c 08:45
# 17         June 17, 1917      NaN
# 18       August 21, 1917  c 07:00
# 19      October 20, 1917  c 07:45
# 20        April 07, 1918  c 21:30
# 21          May 10, 1918      NaN
# 22       August 11, 1918  c 10:00
# 23     December 16, 1918      NaN
# 24          May 25, 1919      NaN
# 25         July 19, 1919      NaN
# ...

# %%
aboard = pc['aboard']
aboard
# Out:
# 0            2   (passengers:1  crew:1)
# 1            1   (passengers:0  crew:1)
# 2            5   (passengers:0  crew:5)
# 3            1   (passengers:0  crew:1)
# 4           20   (passengers:?  crew:?)
# 5           30   (passengers:?  crew:?)
# 6           41   (passengers:?  crew:?)
# 7           19   (passengers:?  crew:?)
# 8           20   (passengers:?  crew:?)
# 9           22   (passengers:?  crew:?)
# 10         19   (passengers:0  crew:19)
# 11          28   (passengers:?  crew:?)
# 12          20   (passengers:?  crew:?)
# 13          20   (passengers:?  crew:?)
# 14          23   (passengers:?  crew:?)
# 15          21   (passengers:?  crew:?)
# 16          24   (passengers:?  crew:?)
# 17          16   (passengers:?  crew:?)
# 18          18   (passengers:?  crew:?)
# 19          18   (passengers:?  crew:?)
# 20          23   (passengers:?  crew:?)
# 21          22   (passengers:?  crew:?)
# 22          19   (passengers:?  crew:?)
# ...

# %%
aboard.str.extract(r'(\d+)?\D*(\d+)?\D*(\d+)?').head(10)
# Out:
#     0    1    2
# 0   2    1    1
# 1   1    0    1
# 2   5    0    5
# 3   1    0    1
# 4  20  NaN  NaN
# 5  30  NaN  NaN
# 6  41  NaN  NaN
# 7  19  NaN  NaN
# 8  20  NaN  NaN
# 9  22  NaN  NaN

# %%
aad = pd.read_csv(r'udemy/Master Data Analysis/data/tidy/average_arrival_delay.csv')
aad
# Out:
#    airline   ATL   DEN   DFW   IAH   LAS   LAX   MSP   ORD   PHX   SFO
# 0       AA   4.0   9.0   5.0  11.0   8.0   3.0   1.0   8.0   5.0   3.0
# 1       AS   6.0  -3.0  -5.0   1.0   2.0  -3.0   6.0   2.0  -9.0   4.0
# 2       B6   NaN  12.0   4.0   NaN  11.0   2.0   NaN  23.0  20.0   5.0
# 3       DL   0.0  -3.0  10.0   3.0  -3.0   3.0  -1.0   7.0  -4.0   0.0
# 4       EV   7.0  14.0  10.0   3.0   NaN   NaN  10.0   8.0 -14.0   NaN
# 5       F9  20.0  10.0  26.0   1.0  10.0   8.0  35.0  22.0  16.0  15.0
# 6       HA   NaN   NaN   NaN   NaN  13.0   1.0   NaN   NaN   2.0   8.0
# 7       MQ  21.0   NaN   8.0   7.0   NaN  28.0  72.0   6.0   NaN   NaN
# 8       NK  26.0   8.0  15.0  28.0  13.0  24.0  19.0  23.0   4.0   NaN
# 9       OO   9.0   7.0  23.0  12.0  -3.0   8.0   2.0  10.0   3.0   9.0
# 10      UA   5.0   6.0   8.0   9.0   6.0   4.0   6.0  13.0   0.0   5.0
# 11      US   1.0  -0.0   2.0  -3.0  -5.0   4.0  -3.0   2.0   3.0   3.0
# ...

# %%
aad.melt(id_vars = 'airline').head(10)
# Out:
#   airline variable  value
# 0      AA      ATL    4.0
# 1      AS      ATL    6.0
# 2      B6      ATL    NaN
# 3      DL      ATL    0.0
# 4      EV      ATL    7.0
# 5      F9      ATL   20.0
# 6      HA      ATL    NaN
# 7      MQ      ATL   21.0
# 8      NK      ATL   26.0
# 9      OO      ATL    9.0

# %%
aapl = pd.read_json('https://api.iextrading.com/1.0/stock/aapl/chart/5y')
aapl = aapl.set_index('date')
aapl
# Out:
#                change  changeOverTime  changePercent     close      high  \
# date
# 2014-06-02  -0.569551        0.000000         -0.687   82.3104   83.1195
# 2014-06-03   1.164000        0.014140          1.414   83.4743   83.6315
# 2014-06-04   0.953183        0.025721          1.142   84.4275   84.8295
# 2014-06-05   0.331260        0.029746          0.392   84.7588   85.0233
# 2014-06-06  -0.233059        0.026914         -0.275   84.5257   85.2707
# 2014-06-09   1.352600        0.043347          1.600   85.8783   86.0433
# 2014-06-10   0.504088        0.049471          0.587   86.3824   87.1156
# 2014-06-11  -0.357443        0.045128         -0.414   86.0249   86.8498
# 2014-06-12  -1.438900        0.027647         -1.673   84.5860   86.2632
# 2014-06-13  -0.925693        0.016400         -1.094   83.6603   84.7235
# 2014-06-16   0.843204        0.026644          1.008   84.5035   85.0076
# 2014-06-17  -0.109982        0.025308         -0.130   84.3935   84.9618
# ...

# %%
aapl['2017-02':'2017-03']
# Out:
#               change  changeOverTime  changePercent     close      high  \
# date
# 2017-02-01  7.117100        0.504403          6.098  123.8280  125.5014
# 2017-02-02 -0.211591        0.501832         -0.171  123.6164  124.4435
# 2017-02-03  0.528975        0.508259          0.428  124.1454  124.2511
# 2017-02-06  1.163700        0.522397          0.937  125.3091  125.5111
# 2017-02-07  1.192600        0.536886          0.952  126.5017  127.0403
# 2017-02-08  0.490501        0.542845          0.388  126.9922  127.1653
# 2017-02-09  0.917660        0.553994          0.723  127.9099  127.9340
# 2017-02-10 -0.289781        0.550474         -0.227  127.6201  128.4121
# 2017-02-13  1.130200        0.564203          0.886  128.7502  129.2622
# 2017-02-14  1.671100        0.584506          1.298  130.4213  130.4889
# 2017-02-15  0.473311        0.590256          0.363  130.8946  131.6287
# 2017-02-16 -0.159380        0.588319         -0.122  130.7352  131.2713
# ...

# %%
aapl_mc = aapl.resample('M').agg({'close':'mean'})
aapl_mc
# Out:
#                  close
# date
# 2014-06-30   84.215200
# 2014-07-31   87.643109
# 2014-08-31   90.585329
# 2014-09-30   92.613495
# 2014-10-31   93.673665
# 2014-11-30  104.728500
# 2014-12-31  103.988605
# 2015-01-31  102.351760
# 2015-02-28  116.422821
# 2015-03-31  116.992314
# 2015-04-30  118.218929
# 2015-05-31  119.985140
# 2015-06-30  119.193014
# 2015-07-31  116.888618
# 2015-08-31  106.161295
# 2015-09-30  105.671924
# 2015-10-31  106.198777
# 2015-11-30  111.098150
# 2015-12-31  105.116777
# 2016-01-31   92.605626
# 2016-02-29   90.497370
# 2016-03-31   98.630859
# 2016-04-30  100.969010
# 2016-05-31   90.310086
# 2016-06-30   91.955645
# 2016-07-31   93.796455
# 2016-08-31  102.949417
# 2016-09-30  106.074538
# 2016-10-31  110.715281
# 2016-11-30  105.890976
# 2016-12-31  109.964738
# 2017-01-31  114.998920
# 2017-02-28  128.988500
# 2017-03-31  135.828461
# 2017-04-30  138.020205
# 2017-05-31  147.433005
# 2017-06-30  143.385777
# 2017-07-31  143.839835
# ...

# %%
# %matplotlib inline

# %%
aapl_mc.plot(kind='line',figsize=(10,4))

# %%
aapl_mc.plot(kind='bar',figsize=(10,4))

# %% [markdown]
# data frames and series

# %%
import pandas as pd

# %%
bikes = pd.read_csv('udemy/Master Data Analysis/data/bikes.csv')

# %%
bikes.head(2)

# %%
events = bikes['events']
events.head(10)
# Out:
# 0    mostlycloudy
# 1    partlycloudy
# 2    mostlycloudy
# 3    mostlycloudy
# 4    partlycloudy
# 5    mostlycloudy
# 6          cloudy
# 7          cloudy
# 8          cloudy
# 9    mostlycloudy
# Name: events, dtype: object

# %%
type(events)
# Out:
# pandas.core.series.Series

# %%
bikes_last_2 = bikes.tail(2)

# %%
bikes_last_2
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 50087  17535645  Subscriber  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246  Subscriber    Male  2017-12-31 15:22:00  2017-12-31 15:26:00
#
#        tripduration           from_station_name  latitude_start  \
# 50087           178        Clinton St & Lake St       41.885637
# 50088           214  Clarendon Ave & Leland Ave       41.967968
#
#        longitude_start  dpcapacity_start             to_station_name  \
# 50087       -87.641823              23.0    Kingsbury St & Kinzie St
# 50088       -87.650001              15.0  Clifton Ave & Lawrence Ave
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 50087     41.889177     -87.638506            31.0          7.0        10.0
# 50088     41.968812     -87.657659            15.0         10.9        10.0
#
#        wind_speed  precipitation        events
# ...

# %%
bikes.head()
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4    13168  Subscriber   Male  2013-07-01 11:16:00  2013-07-01 11:18:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
# 3           667       Carpenter St & Huron St       41.894556
# 4           130        Damen Ave & Pierce Ave       41.909396
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St     41.900960
# ...

# %%
#missing values

# %%
bikes.dtypes
# Out:
# trip_id                int64
# usertype              object
# gender                object
# starttime             object
# stoptime              object
# tripduration           int64
# from_station_name     object
# latitude_start       float64
# longitude_start      float64
# dpcapacity_start     float64
# to_station_name       object
# latitude_end         float64
# longitude_end        float64
# dpcapacity_end       float64
# temperature          float64
# visibility           float64
# wind_speed           float64
# precipitation        float64
# events                object
# dtype: object

# %%
bikes = pd.read_csv(r'udemy/Master Data Analysis/data/bikes.csv',parse_dates = ['starttime','stoptime'])
bikes.dtypes
# Out:
# trip_id                       int64
# usertype                     object
# gender                       object
# starttime            datetime64[ns]
# stoptime             datetime64[ns]
# tripduration                  int64
# from_station_name            object
# latitude_start              float64
# longitude_start             float64
# dpcapacity_start            float64
# to_station_name              object
# latitude_end                float64
# longitude_end               float64
# dpcapacity_end              float64
# temperature                 float64
# visibility                  float64
# wind_speed                  float64
# precipitation               float64
# events                       object
# dtype: object

# %%
bikes.shape
# Out:
# (50089, 19)

# %%
bikes.size
# Out:
# 951691

# %%
len(bikes)
# Out:
# 50089

# %%
df = pd.read_csv(r'udemy/Master Data Analysis/data/sample_data.csv',index_col = 0)
df
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %%
df
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5
# Cornelia     TX    red   Beans   69     150    2.2

# %%
df.index
# Out:
# Index(['Jane', 'Niko', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'], dtype='object')

# %%
df.columns
# Out:
# Index(['state', 'color', 'food', 'age', 'height', 'score'], dtype='object')

# %%
df.values
# Out:
# array([['NY', 'blue', 'Steak', 30, 165, 4.6],
#        ['TX', 'green', 'Lamb', 2, 70, 8.3],
#        ['FL', 'red', 'Mango', 12, 120, 9.0],
#        ['AL', 'white', 'Apple', 4, 80, 3.3],
#        ['AK', 'gray', 'Cheese', 32, 180, 1.8],
#        ['TX', 'black', 'Melon', 33, 172, 9.5],
#        ['TX', 'red', 'Beans', 69, 150, 2.2]], dtype=object)
